# %% [markdown]
# <a href="https://colab.research.google.com/github/MennaAyman5/fish/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.simplefilter("ignore")

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6cf64636-e5a6-4b93-a0eb-f872b608a4ce" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6cf64636-e5a6-4b93-a0eb-f872b608a4ce">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('Fish.csv',
                 lineterminator='\n')

# %%
 df.head()
# Out:
#   Species  Weight  Length1  Length2  Length3   Height  Width\r
# 0   Bream   242.0     23.2     25.4     30.0  11.5200   4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800   4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778   4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300   4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440   5.1340

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Species          159 non-null    object
#  1   Weight           159 non-null    float64
#  2   Vertical length  159 non-null    float64
#  3   Length2          159 non-null    float64
#  4   Length3          159 non-null    float64
#  5   Height           159 non-null    float64
#            159 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 8.8+ KB

# %%
df.rename({'Length1':'Vertical length'},axis='columns',inplace=True)
df.rename({'Length2':'Diagonal length'},axis='columns',inplace=True)
df.rename({'Length3':'Cross length'},axis='columns',inplace=True)

# %%
df.head()
# Out:
#   Species  Weight  Vertical length  Diagonal length  Cross length   Height  \
# 0   Bream   242.0             23.2             25.4          30.0  11.5200
# 1   Bream   290.0             24.0             26.3          31.2  12.4800
# 2   Bream   340.0             23.9             26.5          31.1  12.3778
# 3   Bream   363.0             26.3             29.0          33.5  12.7300
# 4   Bream   430.0             26.5             29.0          34.0  12.4440
#
#    Width\r
# 0   4.0200
# 1   4.3056
# 2   4.6961
# 3   4.4555
# 4   5.1340

# %%
df.describe()
# Out:
#             Weight  Vertical length  Diagonal length  Cross length  \
# count   159.000000       159.000000       159.000000    159.000000
# mean    398.326415        26.247170        28.415723     31.227044
# std     357.978317         9.996441        10.716328     11.610246
# min       0.000000         7.500000         8.400000      8.800000
# 25%     120.000000        19.050000        21.000000     23.150000
# 50%     273.000000        25.200000        27.300000     29.400000
# 75%     650.000000        32.700000        35.500000     39.650000
# max    1650.000000        59.000000        63.400000     68.000000
#
#            Height     Width\r
# count  159.000000  159.000000
# mean     8.970994    4.417486
# std      4.286208    1.685804
# min      1.728400    1.047600
# 25%      5.944800    3.385650
# 50%      7.786000    4.248500
# 75%     12.365900    5.584500
# max     18.957000    8.142000

# %%
df.isna().sum()
# Out:
# Species            0
# Weight             0
# Vertical length    0
# Diagonal length    0
# Cross length       0
# Height             0
# Width\r            0
# dtype: int64

# %%
s = df["Species"].value_counts()
s = pd.DataFrame(s)
s.T
# Out:
#          Perch  Bream  Roach  Pike  Smelt  Parkki  Whitefish
# Species     56     35     20    17     14      11          6

# %%
sns.barplot(x=s.index, y=s['Species'],color="lightblue");
plt.xlabel('Species')
plt.ylabel('Counts of Species')
plt.show()

# %%
sns.pairplot(df, kind='scatter',hue = "Species")
plt.show()

# %%
df_corr = df.corr()
df_corr
# Out:
#                    Weight  Vertical length  Diagonal length  Cross length  \
# Weight           1.000000         0.915712         0.918618      0.923044
# Vertical length  0.915712         1.000000         0.999517      0.992031
# Diagonal length  0.918618         0.999517         1.000000      0.994103
# Cross length     0.923044         0.992031         0.994103      1.000000
# Height           0.724345         0.625378         0.640441      0.703409
# Width\r          0.886507         0.867050         0.873547      0.878520
#
#                    Height   Width\r
# Weight           0.724345  0.886507
# Vertical length  0.625378  0.867050
# Diagonal length  0.640441  0.873547
# Cross length     0.703409  0.878520
# Height           1.000000  0.792881
# Width\r          0.792881  1.000000

# %%
sns.heatmap(df_corr,annot=True,cmap='YlGnBu')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso
import sklearn
from sklearn import linear_model

# %%
df.columns
# Out:
# Index(['Species', 'Weight', 'Vertical length', 'Diagonal length',
#        'Cross length', 'Height', 'Width\r'],
#       dtype='object')

# %%
X_train, X_test, y_train, y_test=train_test_split(df[['Vertical length','Diagonal length','Cross length','Height','Width\r']],
                                    df['Weight'],test_size=0.2,random_state=41)

# %%
#print('X_train \n' , X_train)
#print('X_test \n' , X_test)
#print('y_train \n' ,y_train)
#print('y_test \n' , y_test)

# %%
print('How many samples do we have in our test and train datasets?')
print('X_train: ', np.shape(X_train))
print('y_train: ', np.shape(y_train))
print('X_test: ', np.shape(X_test))
print('y_test: ', np.shape(y_test))
# Out:
# How many samples do we have in our test and train datasets?
# X_train:  (127, 5)
# y_train:  (127,)
# X_test:  (32, 5)
# y_test:  (32,)

# %%
model= linear_model.LinearRegression()

model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred= model.predict(X_test)
y_pred
# Out:
# array([ 373.29771674,   32.71232206,  419.30318536,  769.5837286 ,
#         371.66498247,   43.00711173,  275.43967606,  785.83004232,
#         230.60029716,  619.52228417,  488.42761873,  -75.27111092,
#        -216.53898566, -158.91311694,  100.27815646,  323.65807094,
#         373.07523531,  368.90105239,  912.75324307,  193.3757327 ,
#          35.51394958,  605.83038716,  166.22772245,  123.70455464,
#         174.83041506,  881.26240827,  631.03622898,  699.45493447,
#         700.68174092,  183.1988814 ,  197.00019094,  651.5421178 ,
#         211.00641067,  317.47318244, -124.06965264,  710.44837522,
#        1212.33051044,  238.8910987 ,  500.25228598,  228.83533247])

# %%
model.score(X_train, y_train)
# Out:
# 0.9006904983640043

# %% [markdown]
# --------

# %%
print('Model intercept: ', model.intercept_)
print('Model coefficients: ', model.coef_)
# Out:
# Model intercept:  -502.52211627382457
# Model coefficients:  [ 88.62331216 -17.17780697 -40.24569557  34.88817268   2.63904765]

# %%
# The intercept (sometimes called the “constant”) in a regression model
# represents the mean value of the response variable 
# when all of the predictor variables in the model are equal to zero.

# %%
from sklearn.linear_model import SGDRegressor
from sklearn.preprocessing import StandardScaler
#from lab_utils_multi import  load_house_data
#from lab_utils_common import dlc

# %%
scaler = StandardScaler()
X_norm = scaler.fit_transform(X_train)
print(f"Peak to Peak range by column in Raw        X:{np.ptp(X_train,axis=0)}")   
print(f"Peak to Peak range by column in Normalized X:{np.ptp(X_norm,axis=0)}")
# Out:
# Peak to Peak range by column in Raw        X:[51.5    55.     59.2    17.2286  7.0944]
# Peak to Peak range by column in Normalized X:[5.3297963  5.30665219 5.23558945 4.01463368 4.22936338]

# %%
sgdr = SGDRegressor(max_iter=1000)
sgdr.fit(X_norm, y_train)
print(sgdr)
print(f"number of iterations completed: {sgdr.n_iter_}, number of weight updates: {sgdr.t_}")
# Out:
# SGDRegressor()
# number of iterations completed: 39, number of weight updates: 4954.0

# %%
b_norm = sgdr.intercept_
w_norm = sgdr.coef_
print(f"model parameters:                   w: {w_norm}, b:{b_norm}")
print( "model parameters from previous lab: w: [110.56 -21.27 -32.71 -37.97], b: 363.16")
# Out:
# model parameters:                   w: [85.53718952 81.64910825 71.1939337  47.92686982 69.46586402], b:[392.09745541]
# model parameters from previous lab: w: [110.56 -21.27 -32.71 -37.97], b: 363.16

# %%
# make a prediction using sgdr.predict()
y_pred_sgd = sgdr.predict(X_norm)
# make a prediction using w,b. 
y_pred = np.dot(X_norm, w_norm) + b_norm  
print(f"prediction using np.dot() and sgdr.predict match: {(y_pred == y_pred_sgd).all()}")

print(f"Prediction on training set:\n{y_pred[:4]}" )
print(f"Target values \n{y_train[:4]}")
# Out:
# prediction using np.dot() and sgdr.predict match: True
# Prediction on training set:
# [289.33548002  -7.12743296 406.4431928  414.19268737]
# Target values
# 51     180.0
# 62      60.0
# 128    200.0
# 2      340.0
# Name: Weight, dtype: float64
